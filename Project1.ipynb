# %%
#this is the first project of the developer shrey D patel

# %%
print("Welcome to the Interactive Personal Data Collector application!")
a= str(input("Enter your name:"))
b= int(input("Enter your age:"))
c= float(input("Enter your height in meters:"))
d= int(input("Enter your favorite number:"))
print(" ")
print("Thank you! Here is the summary of your data:")
print(" ")
print("Name:", a,"(Type:",type(a),", Memory Address: ",id(a),")")
print("Age:", b,"(Type:",type(b),", Memory Address: ",id(b),")")
print("Height:", c,"(Type:",type(c),", Memory Address: ",id(c),")")
print("Favourite Number:", d,"(Type:",type(d),", Memory Address: ",id(d),")")
print(" ")
current_year=2026
birth_year=current_year-b
print("Birth Year:", birth_year,"(based on your age of ",b,")")
print(" ")
print("Thank you for using the personal data collector. Goodbye!")
# Out:
# Welcome to the Interactive Personal Data Collector application!
# Enter your name:shrey
# Enter your age:24
# Enter your height in meters:1.68
# Enter your favorite number:7
#
# Thank you! Here is the summary of your data:
#
# Name: shrey (Type: <class 'str'> , Memory Address:  134946940239088 )
# Age: 24 (Type: <class 'int'> , Memory Address:  11655112 )
# Height: 1.68 (Type: <class 'float'> , Memory Address:  134946953077680 )
# Favourite Number: 7 (Type: <class 'int'> , Memory Address:  11654568 )
#
# Birth Year: 2002 (based on your age of  24 )
#
# Thank you for using the personal data collector. Goodbye!
